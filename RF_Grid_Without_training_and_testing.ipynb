# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset=dataset.astype(int)

# %%
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[["age","bmi","children","sex_male","smoker_yes"]]
dep=dataset[["charges"]]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={'criterion':['squared_error','friedman_mse','absolute_error','poisson'],
            'max_features':['sqrt','log2'],'n_estimators':[10,100]}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1,error_score='raise')
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(error_score='raise', estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_Score value for best parameter{}:".format(grid.best_params_))
# Out:
# The R_Score value for best parameter{'criterion': 'squared_error', 'max_features': 'log2', 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.020458      0.001068         0.002601        0.000489
# 1        0.171852      0.005071         0.010009        0.000895
# 2        0.024627      0.003631         0.003664        0.001071
# 3        0.179157      0.005176         0.010711        0.001167
# 4        0.020269      0.002869         0.002400        0.000490
# 5        0.162105      0.004742         0.009030        0.000575
# 6        0.021524      0.002238         0.004104        0.000803
# 7        0.162826      0.002578         0.009107        0.000802
# 8        0.065636      0.002879         0.002503        0.000317
# 9        0.580812      0.048500         0.007183        0.000896
# 10       0.067381      0.002303         0.002401        0.000489
# 11       0.561323      0.054522         0.007397        0.000775
# 12       0.031331      0.004695         0.002500        0.000448
# 13       0.227908      0.016060         0.008305        0.000679
# 14       0.027224      0.001992         0.002303        0.000402
# 15       0.227502      0.007624         0.008091        0.000511
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               sqrt                  10
# 1    squared_error               sqrt                 100
# 2    squared_error               log2                  10
# 3    squared_error               log2                 100
# 4     friedman_mse               sqrt                  10
# 5     friedman_mse               sqrt                 100
# 6     friedman_mse               log2                  10
# 7     friedman_mse               log2                 100
# 8   absolute_error               sqrt                  10
# 9   absolute_error               sqrt                 100
# 10  absolute_error               log2                  10
# 11  absolute_error               log2                 100
# 12         poisson               sqrt                  10
# 13         poisson               sqrt                 100
# 14         poisson               log2                  10
# 15         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.842029
# 1   {'criterion': 'squared_error', 'max_features':...           0.855484
# 2   {'criterion': 'squared_error', 'max_features':...           0.839369
# 3   {'criterion': 'squared_error', 'max_features':...           0.860309
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.830945
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.852964
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.849606
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.852843
# 8   {'criterion': 'absolute_error', 'max_features'...           0.838534
# 9   {'criterion': 'absolute_error', 'max_features'...           0.857510
# 10  {'criterion': 'absolute_error', 'max_features'...           0.835302
# 11  {'criterion': 'absolute_error', 'max_features'...           0.860415
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.833922
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.855723
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.835303
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.857689
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.741433           0.837082           0.798239
# 1            0.775989           0.853648           0.820228
# 2            0.745382           0.831362           0.813580
# 3            0.775026           0.852597           0.823873
# 4            0.775649           0.832414           0.803835
# 5            0.771452           0.847255           0.826511
# 6            0.765376           0.834834           0.815965
# 7            0.771179           0.844937           0.819790
# 8            0.753390           0.846094           0.806520
# 9            0.770667           0.854931           0.824247
# 10           0.763373           0.852279           0.818937
# 11           0.771745           0.851840           0.823716
# 12           0.778445           0.811269           0.810315
# 13           0.771591           0.848378           0.827196
# 14           0.756082           0.854718           0.804850
# 15           0.774389           0.852320           0.824638
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.831053         0.809967        0.037529               14
# 1            0.832894         0.827649        0.028990                5
# 2            0.820498         0.810038        0.033518               13
# 3            0.841931         0.830747        0.030425                1
# 4            0.820136         0.812596        0.021110               12
# 5            0.837296         0.827096        0.029244                7
# 6            0.832338         0.819624        0.029148               10
# 7            0.837264         0.825203        0.029144                8
# 8            0.804162         0.809740        0.032764               16
# 9            0.840530         0.829577        0.031755                3
# 10           0.834043         0.820787        0.030587                9
# 11           0.841145         0.829772        0.031493                2
# 12           0.815337         0.809858        0.017878               15
# 13           0.835253         0.827628        0.029727                6
# 14           0.828335         0.815858        0.033877               11
# 15           0.836691         0.829145        0.029757                4

# %%
import pickle
filename="finalized_model_RF_Grid_no_test_train_.sav"

# %%
pickle.dump(grid,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("finalized_model_RF_Grid_no_test_train_.sav",'rb'))

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 46
# BMI: 35
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=loaded_model.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[11623.68]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

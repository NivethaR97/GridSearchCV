# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset=dataset.astype(int)

# %%
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[["age","bmi","children","sex_male","smoker_yes"]]
dep=dataset[["charges"]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(indep,dep,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid={'criterion':['squared_error','friedman_mse','absolute_error','poisson'],
            'max_features':['sqrt','log2'],'n_estimators':[10,100]}
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1,error_score='raise')
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(error_score='raise', estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions=grid.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)
print("The R_Score value for best parameter{}:".format(grid.best_params_),r_score)
# Out:
# The R_Score value for best parameter{'criterion': 'absolute_error', 'max_features': 'log2', 'n_estimators': 100}: 0.8694548199071415

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.018265      0.006091         0.002502    4.475038e-04
# 1        0.128658      0.002472         0.007053    8.502096e-04
# 2        0.014942      0.001422         0.001737    2.236234e-04
# 3        0.127053      0.001571         0.006450    3.951374e-04
# 4        0.014691      0.001194         0.001543    4.562297e-04
# 5        0.127114      0.001168         0.006620    3.477903e-04
# 6        0.015218      0.000510         0.002000    1.784161e-07
# 7        0.127856      0.001538         0.006302    4.012875e-04
# 8        0.040282      0.002250         0.001603    5.857726e-04
# 9        0.365643      0.008356         0.005754    4.384105e-04
# 10       0.038126      0.001531         0.001799    3.996624e-04
# 11       0.369744      0.004087         0.005946    1.085302e-04
# 12       0.019159      0.001102         0.001400    4.902354e-04
# 13       0.175645      0.001843         0.005481    6.203881e-04
# 14       0.018821      0.000273         0.002104    2.032937e-04
# 15       0.153052      0.011678         0.004405    5.867238e-04
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               sqrt                  10
# 1    squared_error               sqrt                 100
# 2    squared_error               log2                  10
# 3    squared_error               log2                 100
# 4     friedman_mse               sqrt                  10
# 5     friedman_mse               sqrt                 100
# 6     friedman_mse               log2                  10
# 7     friedman_mse               log2                 100
# 8   absolute_error               sqrt                  10
# 9   absolute_error               sqrt                 100
# 10  absolute_error               log2                  10
# 11  absolute_error               log2                 100
# 12         poisson               sqrt                  10
# 13         poisson               sqrt                 100
# 14         poisson               log2                  10
# 15         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.793729
# 1   {'criterion': 'squared_error', 'max_features':...           0.808182
# 2   {'criterion': 'squared_error', 'max_features':...           0.779629
# 3   {'criterion': 'squared_error', 'max_features':...           0.811689
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.766285
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.807508
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.797535
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.807231
# 8   {'criterion': 'absolute_error', 'max_features'...           0.778013
# 9   {'criterion': 'absolute_error', 'max_features'...           0.808630
# 10  {'criterion': 'absolute_error', 'max_features'...           0.810737
# 11  {'criterion': 'absolute_error', 'max_features'...           0.815087
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.796704
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.808709
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.800506
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.807523
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.737954           0.829453           0.807603
# 1            0.763651           0.829109           0.821855
# 2            0.762254           0.803204           0.784293
# 3            0.758915           0.831484           0.822863
# 4            0.748670           0.782556           0.815447
# 5            0.767998           0.829718           0.824071
# 6            0.736069           0.810972           0.795145
# 7            0.762100           0.828073           0.826206
# 8            0.745293           0.824630           0.810245
# 9            0.765626           0.837153           0.824541
# 10           0.754661           0.818127           0.808267
# 11           0.767112           0.838869           0.828987
# 12           0.750675           0.790642           0.786897
# 13           0.769976           0.827367           0.821283
# 14           0.706634           0.810915           0.818523
# 15           0.764727           0.833255           0.825990
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.738464         0.781441        0.037091               11
# 1            0.755640         0.795687        0.030292                8
# 2            0.739373         0.773751        0.021574               15
# 3            0.753909         0.795772        0.032783                7
# 4            0.728375         0.768267        0.029696               16
# 5            0.754035         0.796666        0.030333                4
# 6            0.730256         0.773996        0.033824               14
# 7            0.756273         0.795976        0.030967                5
# 8            0.758740         0.783384        0.030033               10
# 9            0.760267         0.799243        0.031030                2
# 10           0.749128         0.788184        0.029859                9
# 11           0.761243         0.802260        0.032053                1
# 12           0.756232         0.776230        0.018940               13
# 13           0.752217         0.795910        0.029593                6
# 14           0.749380         0.777192        0.042757               12
# 15           0.751883         0.796676        0.032687                3

# %%
import pickle
filename="finalized_model_RF_Grid.sav"

# %%
pickle.dump(grid,open(filename,'wb'))
pickle.dump(sc,open("StandardScaler.sav",'wb'))

# %%
loaded_model=pickle.load(open("finalized_model_RF_Grid.sav",'rb'))
sc=pickle.load(open("StandardScaler.sav",'rb'))

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 64
# BMI: 34
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
preinput=sc.transform([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
Future_Prediction=loaded_model.predict(preinput)
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[17457.81]
